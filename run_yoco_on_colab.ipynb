# %% [markdown]
# # Run YOCO on Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Install detectron2

# %%
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'

# %%
# set the path
# %cd /content/drive/MyDrive/modified-unbiased-teacher-v2/
# Out:
# /content/drive/.shortcut-targets-by-id/1-7J_TRvdc7-rm34xRrWk_K88p-_mE4y8/modified-unbiased-teacher-v2

# %% [markdown]
# ## Inference only (Test only)

# %%
# !python /content/drive/MyDrive/modified-unbiased-teacher-v2/train_net_sy.py \
      --test-only \
      --num-gpus 1 \
      --config /content/drive/MyDrive/modified-unbiased-teacher-v2/Jisoo/output_40_20000_50000/config.yaml  \
      --output_dir /content/drive/MyDrive/output \
      --video_input  "/content/drive/MyDrive/COOK/jw_demo/bacon_from_youtube_4.mp4" \
      MODEL.WEIGHTS /content/drive/MyDrive/COOK/modified-unbiased-teacher-v2/Jisoo/output_40_20000_50000/model_final.pth \
      MODEL.FCOS.INFERENCE_TH_TEST 0.4
# Out:
# Command Line Args: Namespace(config_file='/content/drive/MyDrive/modified-unbiased-teacher-v2/Jisoo/output_40_20000_50000/config.yaml', dist_url='tcp://127.0.0.1:49152', eval_only=False, machine_rank=0, max_frame=0, num_gpus=1, num_machines=1, opts=['MODEL.WEIGHTS', '/content/drive/MyDrive/COOK/modified-unbiased-teacher-v2/Jisoo/output_40_20000_50000/model_final.pth', 'MODEL.FCOS.INFERENCE_TH_TEST', '0.4'], output_dir='/content/drive/MyDrive/output', resume=False, test_only=True, video_input='/content/drive/MyDrive/COOK/jw_demo/bacon_from_youtube_4.mp4')
# [02/26 10:34:52 detectron2]: Rank of current process: 0. World size: 1
# [02/26 10:34:53 detectron2]: Environment info:
# ----------------------  ----------------------------------------------------------------
# sys.platform            linux
# Python                  3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
# numpy                   1.22.4
# detectron2              0.6 @/usr/local/lib/python3.8/dist-packages/detectron2
# ...

# %% [markdown]
# ## How to Train

# %%
# !python /content/drive/MyDrive/modified-unbiased-teacher-v2/train_net.py \
      --num-gpus 1 \
      --config /content/drive/MyDrive/modified-unbiased-teacher-v2/configs/FCOS/coco-standard/soyeong_v2_fcos_R_50_ut2_sup40_run0.yaml \
      SEMISUPNET.BURN_UP_STEP 5000 \
      SOLVER.CHECKPOINT_PERIOD 1000
# Out:
# Command Line Args: Namespace(config_file='/content/drive/MyDrive/modified-unbiased-teacher-v2/configs/FCOS/coco-standard/soyeong_v2_fcos_R_50_ut2_sup40_run0.yaml', dist_url='tcp://127.0.0.1:49152', eval_only=False, machine_rank=0, num_gpus=1, num_machines=1, opts=['SEMISUPNET.BURN_UP_STEP', '5000', 'SOLVER.CHECKPOINT_PERIOD', '1000'], resume=False)
# [02/23 03:08:15 detectron2]: Rank of current process: 0. World size: 1
# [02/23 03:08:17 detectron2]: Environment info:
# ----------------------  ----------------------------------------------------------------
# sys.platform            linux
# Python                  3.8.10 (default, Nov 14 2022, 12:59:47) [GCC 9.4.0]
# numpy                   1.22.4
# detectron2              0.6 @/usr/local/lib/python3.8/dist-packages/detectron2
# Compiler                GCC 9.4
# CUDA compiler           CUDA 11.6
# detectron2 arch flags   7.5
# DETECTRON2_ENV_MODULE   <not set>
# ...

# %% [markdown]
# ### How to resume train

# %%
# !python /content/drive/MyDrive/modified-unbiased-teacher-v2/train_net.py \
      --resume \
      --num-gpus 1 \
      --config /content/drive/MyDrive/modified-unbiased-teacher-v2/configs/FCOS/coco-standard/soyeong_v2_fcos_R_50_ut2_sup40_run0.yaml \
      SOLVER.CHECKPOINT_PERIOD 1000 \
      MODEL.WEIGHTS /content/drive/MyDrive/output/ckpt/model_0004999.pth
